# %% [markdown]
# # Linear Regression Analysis (R)
#
# This notebook loads salary data, visualizes the relationship between years of experience and salary, fits a linear regression model, overlays the regression line on a scatter plot, and evaluates model performance.

# %%
library(ggplot2)

# %%
df <- read.csv("regression_data.csv", stringsAsFactors = FALSE)

print("First rows:")
print(head(df))
print(paste("\nDimensions:", nrow(df), "rows,", ncol(df), "columns"))
print("\nStructure:")
str(df)
# Out:
# [1] "First rows:"
#   YearsExperience Salary
# 1             1.1  39343
# 2             1.3  46205
# 3             1.5  37731
# 4             2.0  43525
# 5             2.2  39891
# 6             2.9  56642
# [1] "\nDimensions: 10 rows, 2 columns"
# [1] "\nStructure:"
# 'data.frame':	10 obs. of  2 variables:
#  $ YearsExperience: num  1.1 1.3 1.5 2 2.2 2.9 3 3.2 3.7 4
#  $ Salary         : num  39343 46205 37731 43525 39891 ...

# %%
ggplot(df, aes(x = YearsExperience, y = Salary)) +
  geom_point(color = "steelblue", size = 3) +
  labs(
    x = "Years of Experience",
    y = "Salary",
    title = "Salary vs. Years of Experience"
  ) +
  theme_minimal()
# Out:
# plot without title

# %%
model <- lm(Salary ~ YearsExperience, data = df)

intercept <- coef(model)[1]
slope <- coef(model)[2]

cat(sprintf("Intercept: %.2f\n", intercept))
cat(sprintf("Slope: %.2f\n", slope))
cat(sprintf("Regression equation: Salary = %.2f + %.2f * YearsExperience\n", intercept, slope))
# Out:
# Intercept: 29203.52
# Slope: 8285.29
# Regression equation: Salary = 29203.52 + 8285.29 * YearsExperience

# %%
ggplot(df, aes(x = YearsExperience, y = Salary)) +
  geom_point(color = "steelblue", size = 3) +
  geom_abline(intercept = intercept, slope = slope, color = "crimson", linewidth = 1) +
  labs(
    x = "Years of Experience",
    y = "Salary",
    title = "Salary vs. Years of Experience with Regression Line"
  ) +
  theme_minimal()
# Out:
# ERROR while rich displaying an object: Error in `geom_abline()`:
# ! Problem while converting geom to grob.
# ℹ Error occurred in the 2nd layer.
# Caused by error:
# ! Unknown colour name: crimson
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.default(obj)
# 11. paste(capture.output(print(obj)), collapse = "\n")
# 12. capture.output(print(obj))
# 13. withVisible(...elt(i))
# 14. print(obj)
# 15. `print.ggplot2::ggplot`(obj)
# 16. ggplot_gtable(data)
# 17. `ggplot_gtable.ggplot2::ggplot_built`(data)
# 18. by_layer(function(l, d) l$draw_geom(d, layout), plot@layers,
#   .     data, "converting geom to grob")
# 19. try_fetch(for (i in seq_along(data)) {
#   .     out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   . }, error = function(cnd) {
#   .     cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .         call = layers[[i]]$constructor, parent = cnd)
#   . })
# 20. tryCatch(withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . }), stackOverflowError = handlers[[1L]])
# 21. tryCatchList(expr, classes, parentenv, handlers)
# 22. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 23. doTryCatch(return(expr), name, parentenv, handler)
# 24. withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })
# 25. f(l = layers[[i]], d = data[[i]])
# 26. l$draw_geom(d, layout)
# 27. draw_geom(..., self = self)
# 28. self$geom$draw_layer(data, self$computed_geom_params, layout,
#   .     layout$coord)
# 29. draw_layer(..., self = self)
# 30. lapply(data_panels, function(data) {
#   .     if (empty(data))
#   .         return(zeroGrob())
#   .     panel_params <- layout$panel_params[[data$PANEL[1]]]
#   .     inject(self$draw_panel(data, panel_params, coord, !!!params))
#   . })
# 31. FUN(X[[i]], ...)
# 32. inject(self$draw_panel(data, panel_params, coord, !!!params))
# 33. self$draw_panel(data, panel_params, coord)
# 34. draw_panel(...)
# 35. GeomSegment$draw_panel(unique0(data), panel_params, coord, lineend = lineend)
# 36. draw_panel(..., self = self)
# 37. segmentsGrob(coord$x, coord$y, coord$xend, coord$yend, default.units = "native",
#   .     gp = gg_par(col = alpha(coord$colour, coord$alpha), fill = alpha(arrow.fill,
#   .         coord$alpha), lwd = coord$linewidth, lty = coord$linetype,
#   .         lineend = lineend, linejoin = linejoin), arrow = arrow)
# 38. grob(x0 = x0, y0 = y0, x1 = x1, y1 = y1, arrow = arrow, name = name,
#   .     gp = gp, vp = vp, cl = "segments")
# 39. gg_par(col = alpha(coord$colour, coord$alpha), fill = alpha(arrow.fill,
#   .     coord$alpha), lwd = coord$linewidth, lty = coord$linetype,
#   .     lineend = lineend, linejoin = linejoin)
# 40. list2(...)
# 41. alpha(coord$colour, coord$alpha)
# 42. farver::decode_colour(colour, alpha = TRUE)
# 43. decode_c(colour, alpha, colourspace_match(to), white, na_value)
# 44. .handleSimpleError(function (cnd)
#   . {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . }, "Unknown colour name: crimson", base::quote(NULL))
# 45. h(simpleError(msg, call))
# 46. handlers[[1L]](cnd)
# 47. cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .     call = layers[[i]]$constructor, parent = cnd)
# 48. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 49. signal_abort(cnd, .file)

# %%
y_pred <- predict(model, df)
y <- df$Salary
residuals <- y - y_pred
n <- length(y)

r2 <- summary(model)$r.squared
rmse <- sqrt(mean((y - y_pred)^2))
mae <- mean(abs(y - y_pred))
residual_se <- sqrt(sum(residuals^2) / (n - 2))

cat("Model Performance\n")
cat("-----------------\n")
cat(sprintf("R-squared:              %.4f\n", r2))
cat(sprintf("RMSE:                   %.2f\n", rmse))
cat(sprintf("MAE:                    %.2f\n", mae))
cat(sprintf("Residual Std. Error:    %.2f\n", residual_se))
# Out:
# Model Performance
# -----------------
# R-squared:              0.7852
# RMSE:                   4186.15
# MAE:                    3526.26
# Residual Std. Error:    4680.26

# %% [markdown]
# ## Interpretation
#
# The positive slope indicates that salary tends to increase with years of experience. R-squared shows the proportion of variance in salary explained by the linear model, while RMSE and MAE summarize typical prediction error in salary units.
